# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
import seaborn as sns 

iris = load_iris()
X = iris['data']
y = iris['target']

# %% [markdown]
# ### Descrevendo os dados do Dataset Iris

# %%
print("\nCampos to dataset Ires ({0}):\n{1}\n"
      .format("iris.keys()", iris.keys()))

print("\nCampos to dataset Ires ({0}):\n{1}\n"
      .format("iris['DESCR'][:47]", iris['DESCR'][:47]))

print("\nCampos to dataset Ires ({0}):\n{1}\n"
      .format("iris['target_names']", iris['target_names'])),

print("\nCampos to dataset Ires ({0}):\n{1}\n"
      .format("iris['feature_names']", iris['feature_names']))

# %% [markdown]
# ### Divisão da base original em base de teste e base de treinamento

# %%
X_train, X_teste, y_train,y_teste = train_test_split(iris['data'],iris['target'], random_state=0)

print(f"X_train.shape", X_train.shape)
print("\n")
print(f"X_train.teste", X_teste.shape)

# %% [markdown]
# ### Visualizando os dados

# %%
iris_dataframe = pd.DataFrame(np.c_[iris['data'], iris['target']],
                              columns=np.append(iris['feature_names'], 'target'))

ax2 = pd.plotting.scatter_matrix(iris_dataframe.iloc[:, :4], figsize=(11, 11), c=y, marker='o',
                                 hist_kwds={'bins': 20}, s=60, alpha=.8)

plt.figure()
ax3 = pd.plotting.parallel_coordinates(iris_dataframe, 'target')
